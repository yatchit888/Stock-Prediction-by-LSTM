# %% [markdown]
# # Stock Price Prediction
# ## Introduction
# The project specifically uses the daily closing price data of Maotai's stock. The LSTM and GRU model are trained on a sequence of 60 consecutive days of closing prices to predict the opening price of the 61st day. In comparison with two models, finding out which model could predict the closing price more accurately.
#
# The project uses several Python libraries:
#
# * tensorflow: for building and training the LSTM model
# * matplotlib: for data visualization
# * pandas: for data manipulation and analysis
# * numpy: for numerical computations
# * sklearn: for data preprocessing and performance metrics

# %%
# Using the daily K-line data of Maotai's stock, use the closing price of 60 consecutive days to predict the closing price of the 61st day
import tensorflow.compat.v1 as tf
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dropout,Dense,LSTM,GRU
from tensorflow.keras.regularizers import l1_l2
import pandas as pd

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import mean_squared_error,mean_absolute_error

import math
import os
# Out:
# c:\Users\yatch\AppData\Local\Programs\Python\Python38\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# load data
maotai=pd.read_csv('maotaigupiao.csv')
maotai.head()
# Out:
#    Unnamed: 0        date    open   close    high     low     volume    code
# 0          74  2010-04-26  88.702  87.381  89.072  87.362  107036.13  600519
# 1          75  2010-04-27  87.355  84.841  87.355  84.681   58234.48  600519
# 2          76  2010-04-28  84.235  84.318  85.128  83.597   26287.43  600519
# 3          77  2010-04-29  84.592  85.671  86.315  84.592   34501.20  600519
# 4          78  2010-04-30  83.871  82.340  83.871  81.523   85566.70  600519

# %%
maotai.shape
# Out:
# (2426, 8)

# %%
# Top 2126 rows of data as training set, We only use the data of the opening price that is the close column 
training_set=maotai.iloc[:2426-300,3:4].values
# The last 300 rows of data are used as test set
test_set=maotai.iloc[2426-300:,3:4].values

# %%
plt.plot(training_set,color='blue',label='Stock Price')

# %%
# MinMaxScaler: Normalization to 0-1
sc=MinMaxScaler(feature_range=(0,1))
training_set_scaler=sc.fit_transform(training_set) 
test_set_scaler=sc.transform(test_set)

# %%
training_set_scaler
# Out:
# array([[0.00961659],
#        [0.0060261 ],
#        [0.00528679],
#        ...,
#        [0.83672993],
#        [0.84690772],
#        [0.84309105]])

# %%
test_set_scaler
# Out:
# array([[0.8543997 ],
#        [0.84167747],
#        [0.86090218],
#        [0.86524187],
#        [0.91136703],
#        [0.9009348 ],
#        [0.92543217],
#        [0.92813211],
#        [0.91063197],
#        [0.93214668],
#        [0.91908519],
#        [0.90670221],
#        [0.90422845],
#        [0.91237067],
#        [0.93544032],
#        [0.91426487],
#        [0.93313619],
#        [0.95336454],
#        [1.00183624],
#        [0.9913192 ],
#        [0.98837895],
#        [0.97172696],
#        [0.94430348],
#        [0.92861273],
#        [0.95835448],
#        [0.93922872],
#        [0.95193682],
#        [0.98586277],
#        [0.98487327],
#        [1.0312246 ],
#        [1.0065152 ],
#        [1.00678378],
#        [0.99681803],
#        [1.00848007],
#        [0.98247018],
#        [0.97879487],
#        [1.00070538],
#        [1.02657392],
#        [1.09328082],
#        [1.10036287],
#        [1.08764063],
#        [1.07986594],
#        [1.10884435],
#        [1.15860242],
#        [1.16538761],
#        [1.22615748],
#        [1.19394196],
#        [1.17810984],
#        [1.16821477],
#        [1.2147216 ],
#        [1.23182594],
#        [1.22263766],
#        [1.23261754],
#        [1.22786791],
#        [1.26426763],
#        [1.2572704 ],
#        [1.23234896],
#        [1.22193087],
#        [1.26005516],
#        [1.26292473],
#        [1.16680119],
#        [1.14418389],
#        [1.13626783],
#        [1.10009429],
#        [1.1683844 ],
#        [1.14701105],
#        [1.13933531],
#        [1.1964864 ],
#        [1.20059992],
#        [1.16791792],
#        [1.13705944],
#        [1.1512518 ],
#        [1.14135673],
#        [1.10319003],
#        [1.1279277 ],
#        [1.12863449],
#        [1.14135673],
#        [1.17515546],
#        [1.16581169],
#        [1.14418389],
#        [1.14701105],
#        [1.12340424],
#        [1.11817399],
#        [1.10478738],
#        [1.11743893],
#        [1.17371361],
#        [1.1677907 ],
#        [1.17245552],
#        [1.17669626],
#        [1.17471725],
#        [1.18235059],
#        [1.20356844],
#        [1.26433831],
#        [1.26617597],
#        [1.28144264],
#        [1.27561869],
#        [1.27120832],
#        [1.29451827],
#        [1.27706054],
#        [1.34471455],
#        [1.33501738],
#        [1.28257351],
#        [1.27310251],
#        [1.2994234 ],
#        [1.27827622],
#        [1.26583671],
#        [1.27496844],
#        [1.27352659],
#        [1.28001493],
#        [1.26565294],
#        [1.25444324],
#        [1.24808212],
#        [1.22546482],
#        [1.2372965 ],
#        [1.23892212],
#        [1.23462483],
#        [1.22385334],
#        [1.24737533],
#        [1.2502449 ],
#        [1.26633146],
#        [1.26989368],
#        [1.26094571],
#        [1.24214508],
#        [1.23528921],
#        [1.21829796],
#        [1.22376852],
#        [1.22193087],
#        [1.25964522],
#        [1.24600416],
#        [1.32601287],
#        [1.32505163],
#        [1.36092833],
#        [1.36314765],
#        [1.37685939],
#        [1.37866877],
#        [1.39862854],
#        [1.39297422],
#        [1.44669031],
#        [1.48358479],
#        [1.44520605],
#        [1.45375822],
#        [1.44119148],
#        [1.4595539 ],
#        [1.5004064 ],
#        [1.4958264 ],
#        [1.49757924],
#        [1.47638966],
#        [1.50323357],
#        [1.50109906],
#        [1.49265998],
#        [1.4747499 ],
#        [1.39795002],
#        [1.4396224 ],
#        [1.4396224 ],
#        [1.43256863],
#        [1.51016012],
#        [1.50464715],
#        [1.52220383],
#        [1.51030147],
#        [1.55977682],
#        [1.54564101],
#        [1.53574594],
#        [1.5467012 ],
#        [1.51171506],
#        [1.5358873 ],
#        [1.50720573],
#        [1.51878296],
#        [1.54648916],
#        [1.5541225 ],
#        [1.59794352],
#        [1.53998668],
#        [1.55882972],
#        [1.54817132],
#        [1.53786631],
#        [1.54111755],
#        [1.52431007],
#        [1.51209672],
#        [1.54189502],
#        [1.55170527],
#        [1.57249906],
#        [1.55949411],
#        [1.55413663],
#        [1.56119041],
#        [1.58181456],
#        [1.58098054],
#        [1.57249906],
#        [1.58433073],
#        [1.58946203],
#        [1.58098054],
#        [1.58465586],
#        [1.61632008],
#        [1.62480157],
#        [1.6175923 ],
#        [1.62095663],
#        [1.62808108],
#        [1.6301025 ],
#        [1.62663922],
#        [1.57391264],
#        [1.55703448],
#        [1.56119041],
#        [1.56818763],
#        [1.54818546],
#        [1.48202985],
#        [1.48768417],
#        [1.46648045],
#        [1.47260126],
#        [1.48316071],
#        [1.53998668],
#        [1.52401321],
#        [1.53207063],
#        [1.52440902],
#        [1.4933385 ],
#        [1.53009161],
#        [1.50877481],
#        [1.53995841],
#        [1.53715952],
#        [1.52217556],
#        [1.5064848 ],
#        [1.51072555],
#        [1.50888789],
#        [1.48867368],
#        [1.49065269],
#        [1.53009161],
#        [1.56232127],
#        [1.55836324],
#        [1.48344343],
#        [1.4107288 ],
#        [1.40992306],
#        [1.4333037 ],
#        [1.42427091],
#        [1.44485266],
#        [1.45870575],
#        [1.47534361],
#        [1.45149649],
#        [1.45818273],
#        [1.45093106],
#        [1.45163785],
#        [1.42831375],
#        [1.40612052],
#        [1.40641738],
#        [1.37431494],
#        [1.30521908],
#        [1.35340807],
#        [1.37034278],
#        [1.40004212],
#        [1.40711003],
#        [1.39366687],
#        [1.43820882],
#        [1.43717691],
#        [1.42831375],
#        [1.42407301],
#        [1.43230005],
#        [1.41841868],
#        [1.43608845],
#        [1.46648045],
#        [1.45924291],
#        [1.42291387],
#        [1.40542787],
#        [1.40385879],
#        [1.42321072],
#        [1.38025199],
#        [1.42125998],
#        [1.45941254],
#        [1.48191676],
#        [1.54140027],
#        [1.51948975],
#        [1.46084026],
#        [1.52019654],
#        [1.52375877],
#        [1.49545887],
#        [1.45804137],
#        [1.3943878 ],
#        [1.36343037],
#        [1.31097236],
#        [1.29402352],
#        [1.349549  ],
#        [1.32653589],
#        [1.3788384 ],
#        [1.41290572],
#        [1.39144755],
#        [1.40640324],
#        [1.40145571],
#        [1.45658538],
#        [1.44527673],
#        [1.50464715],
#        [1.49728239],
#        [1.52578019],
#        [1.52551161],
#        [1.5237305 ],
#        [1.53291878],
#        [1.52910211],
#        [1.56133176],
#        [1.56769288],
#        [1.57829474],
#        [1.61914724],
#        [1.6209849 ],
#        [1.58239413],
#        [1.6452985 ],
#        [1.65626789],
#        [1.6538648 ]])

# %%
x_train,y_train,x_test,y_test=[],[],[],[]  # Create empty list
for i in range(60,len(training_set_scaler)):
    x_train.append(training_set_scaler[i-60:i,0])
    y_train.append(training_set_scaler[i,0])
    pass

# Convert the list to array format for train set

np.random.seed(7)
np.random.shuffle(x_train)
np.random.seed(7)
np.random.shuffle(y_train)
np.random.seed(7)

x_train,y_train=np.array(x_train),np.array(y_train)

x_train=np.reshape(x_train,(x_train.shape[0],60,1))

# %%
# convert the list to array format for test set
for i in range(60,len(test_set_scaler)):
    x_test.append(test_set_scaler[i-60:i,0])
    y_test.append(test_set_scaler[i,0])
    pass

x_test,y_test=np.array(x_test),np.array(y_test)

x_test=np.reshape(x_test,(x_test.shape[0],60,1))

# %%
# Create LSTM model
lstm = Sequential()
lstm.add(LSTM(100, return_sequences=True, input_shape=(60, 1),
               kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4),
               bias_regularizer=l1_l2(l1=1e-4, l2=1e-3)))
lstm.add(Dropout(0.2))
lstm.add(LSTM(50, return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(50))
lstm.add(Dropout(0.2))
lstm.add(Dense(1))
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
# Create GRU model
sequence_length = 60
batch_size = 32
epochs = 100
num_units = 128
dropout_rate = 0.2

gru = Sequential()
gru.add(GRU(num_units, input_shape=(x_train.shape[1], x_train.shape[2]), activation='tanh'))
gru.add(Dropout(dropout_rate))
gru.add(Dense(units=1))
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
# Compile model
lstm.compile(optimizer='adam',# Optimizer
              loss='mean_squared_error') # Loss function
gru.compile(optimizer='adam',# Optimizer
            loss='mean_squared_error') # Loss function

# %%
# Train lstm model
history_lstm = lstm.fit(x_train, y_train, epochs=50, batch_size=64, 
          validation_data=(x_train, y_train), callbacks=[early_stopping])
lstm.summary() # Print model structure
# Out:
# Epoch 1/50
# 33/33 [==============================] - 8s 130ms/step - loss: 0.1232 - val_loss: 0.1056
# Epoch 2/50
# 33/33 [==============================] - 3s 105ms/step - loss: 0.1036 - val_loss: 0.0988
# Epoch 3/50
# 33/33 [==============================] - 3s 99ms/step - loss: 0.0972 - val_loss: 0.0925
# Epoch 4/50
# 33/33 [==============================] - 3s 103ms/step - loss: 0.0910 - val_loss: 0.0867
# Epoch 5/50
# 33/33 [==============================] - 3s 101ms/step - loss: 0.0854 - val_loss: 0.0812
# Epoch 6/50
# 33/33 [==============================] - 3s 95ms/step - loss: 0.0799 - val_loss: 0.0758
# Epoch 7/50
# 33/33 [==============================] - 3s 100ms/step - loss: 0.0745 - val_loss: 0.0708
# Epoch 8/50
# 33/33 [==============================] - 3s 101ms/step - loss: 0.0696 - val_loss: 0.0679
# Epoch 9/50
# 33/33 [==============================] - 3s 99ms/step - loss: 0.0653 - val_loss: 0.0616
# Epoch 10/50
# 33/33 [==============================] - 3s 99ms/step - loss: 0.0604 - val_loss: 0.0571
# Epoch 11/50
# 33/33 [==============================] - 3s 105ms/step - loss: 0.0564 - val_loss: 0.0533
# Epoch 12/50
# 33/33 [==============================] - 3s 101ms/step - loss: 0.0522 - val_loss: 0.0492
# Epoch 13/50
# 33/33 [==============================] - 3s 102ms/step - loss: 0.0485 - val_loss: 0.0459
# Epoch 14/50
# 33/33 [==============================] - 3s 105ms/step - loss: 0.0447 - val_loss: 0.0422
# Epoch 15/50
# 33/33 [==============================] - 3s 101ms/step - loss: 0.0418 - val_loss: 0.0390
# Epoch 16/50
# 33/33 [==============================] - 3s 100ms/step - loss: 0.0385 - val_loss: 0.0359
# Epoch 17/50
# 33/33 [==============================] - 3s 100ms/step - loss: 0.0355 - val_loss: 0.0333
# Epoch 18/50
# 33/33 [==============================] - 3s 100ms/step - loss: 0.0327 - val_loss: 0.0304
# Epoch 19/50
# 33/33 [==============================] - 3s 100ms/step - loss: 0.0301 - val_loss: 0.0283
# Epoch 20/50
# 33/33 [==============================] - 3s 100ms/step - loss: 0.0278 - val_loss: 0.0258
# Epoch 21/50
# 33/33 [==============================] - 3s 100ms/step - loss: 0.0256 - val_loss: 0.0234
# Epoch 22/50
# 33/33 [==============================] - 4s 110ms/step - loss: 0.0233 - val_loss: 0.0215
# Epoch 23/50
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0213 - val_loss: 0.0198
# Epoch 24/50
# 33/33 [==============================] - 4s 122ms/step - loss: 0.0196 - val_loss: 0.0178
# Epoch 25/50
# 33/33 [==============================] - 4s 121ms/step - loss: 0.0180 - val_loss: 0.0173
# Epoch 26/50
# 33/33 [==============================] - 4s 116ms/step - loss: 0.0167 - val_loss: 0.0148
# Epoch 27/50
# 33/33 [==============================] - 4s 118ms/step - loss: 0.0152 - val_loss: 0.0133
# Epoch 28/50
# 33/33 [==============================] - 4s 117ms/step - loss: 0.0135 - val_loss: 0.0120
# Epoch 29/50
# 33/33 [==============================] - 4s 116ms/step - loss: 0.0122 - val_loss: 0.0109
# Epoch 30/50
# 33/33 [==============================] - 4s 117ms/step - loss: 0.0114 - val_loss: 0.0098
# Epoch 31/50
# 33/33 [==============================] - 4s 116ms/step - loss: 0.0100 - val_loss: 0.0088
# Epoch 32/50
# 33/33 [==============================] - 4s 116ms/step - loss: 0.0092 - val_loss: 0.0080
# Epoch 33/50
# 33/33 [==============================] - 4s 115ms/step - loss: 0.0081 - val_loss: 0.0072
# Epoch 34/50
# 33/33 [==============================] - 4s 112ms/step - loss: 0.0076 - val_loss: 0.0063
# Epoch 35/50
# 33/33 [==============================] - 4s 116ms/step - loss: 0.0067 - val_loss: 0.0057
# Epoch 36/50
# 33/33 [==============================] - 4s 113ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 37/50
# 33/33 [==============================] - 4s 113ms/step - loss: 0.0056 - val_loss: 0.0045
# Epoch 38/50
# 33/33 [==============================] - 4s 114ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 39/50
# 33/33 [==============================] - 4s 111ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 40/50
# 33/33 [==============================] - 4s 116ms/step - loss: 0.0042 - val_loss: 0.0032
# Epoch 41/50
# 33/33 [==============================] - 4s 115ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 42/50
# 33/33 [==============================] - 4s 110ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 43/50
# 33/33 [==============================] - 4s 111ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 44/50
# 33/33 [==============================] - 4s 113ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 45/50
# 33/33 [==============================] - 4s 111ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 46/50
# 33/33 [==============================] - 4s 112ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 47/50
# 33/33 [==============================] - 4s 114ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 48/50
# 33/33 [==============================] - 4s 115ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 49/50
# 33/33 [==============================] - 4s 113ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 50/50
# 33/33 [==============================] - 4s 116ms/step - loss: 0.0017 - val_loss: 9.8933e-04
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 100)           40800
#
#  dropout (Dropout)           (None, 60, 100)           0
#
#  lstm_1 (LSTM)               (None, 60, 50)            30200
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 91251 (356.45 KB)
# Trainable params: 91251 (356.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train gru model
history_gru = gru.fit(x_train, y_train, epochs=100, batch_size=32, 
          validation_data=(x_train, y_train), callbacks=[early_stopping])
gru.summary() # Print model structure
# Out:
# Epoch 1/100
# 65/65 [==============================] - 4s 37ms/step - loss: 0.0077 - val_loss: 2.1993e-04
# Epoch 2/100
# 65/65 [==============================] - 2s 38ms/step - loss: 6.9278e-04 - val_loss: 2.3755e-04
# Epoch 3/100
# 65/65 [==============================] - 2s 35ms/step - loss: 7.2082e-04 - val_loss: 2.6918e-04
# Epoch 4/100
# 65/65 [==============================] - 2s 32ms/step - loss: 6.8909e-04 - val_loss: 1.5583e-04
# Epoch 5/100
# 65/65 [==============================] - 2s 37ms/step - loss: 5.9240e-04 - val_loss: 1.7453e-04
# Epoch 6/100
# 65/65 [==============================] - 2s 32ms/step - loss: 5.7292e-04 - val_loss: 3.2183e-04
# Epoch 7/100
# 65/65 [==============================] - 2s 35ms/step - loss: 5.3297e-04 - val_loss: 1.5293e-04
# Epoch 8/100
# 65/65 [==============================] - 2s 34ms/step - loss: 5.7844e-04 - val_loss: 1.4767e-04
# Epoch 9/100
# 65/65 [==============================] - 2s 31ms/step - loss: 5.2964e-04 - val_loss: 1.9793e-04
# Epoch 10/100
# 65/65 [==============================] - 2s 31ms/step - loss: 4.5343e-04 - val_loss: 1.4127e-04
# Epoch 11/100
# 65/65 [==============================] - 2s 33ms/step - loss: 5.1396e-04 - val_loss: 1.3991e-04
# Epoch 12/100
# 65/65 [==============================] - 2s 33ms/step - loss: 4.9984e-04 - val_loss: 1.3220e-04
# Epoch 13/100
# 65/65 [==============================] - 2s 31ms/step - loss: 4.4943e-04 - val_loss: 1.5983e-04
# Epoch 14/100
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 128)               50304
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 50433 (197.00 KB)
# Trainable params: 50433 (197.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Draw the loss curve of LSTM model
data={}
data['loss']=history_lstm.history['loss']

data['val_loss']=history_lstm.history['val_loss']
pd.DataFrame(data).plot(figsize=(8,5))
plt.grid(True)
plt.title('Training and Validation Loss of LSTM model')
plt.legend()
plt.show()

# %%
# Draw the loss curve of GRU model
data={}
data['loss']=history_gru.history['loss']

data['val_loss']=history_gru.history['val_loss']
pd.DataFrame(data).plot(figsize=(8,5))
plt.grid(True)
plt.title('Training and Validation Loss of GRU model')
plt.legend()
plt.show()

# %%
# Predict stock price of test set by LSTM model 
predicted_stock_price_lstm=lstm.predict(x_test)
# Inverse normalization to get the real stock price 
predicted_stock_price_lstm=sc.inverse_transform(predicted_stock_price_lstm)
predicted_stock_price_lstm

# Get the real stock price of test set
real_stock_price=sc.inverse_transform(test_set_scaler[60:])
real_stock_price
# Calculate the RMSE value

plt.plot(real_stock_price,color='red',label='Mao Tai stock price') #Truth value is red line

plt.plot(predicted_stock_price_lstm,color='blue',label='Mao Tai predicted stock price') #Predicted value is blue line

plt.title('Mao Tai Price Prediction of LSTM model')

plt.xlabel('Time')

plt.ylabel('Stock Price')

plt.legend()
plt.show()
# Out:
# 8/8 [==============================] - 1s 13ms/step

# %%
# Predict stock price of test set by GRU model 
predicted_stock_price_gru=gru.predict(x_test)
# Inverse normalization to get the real stock price 
predicted_stock_price_gru=sc.inverse_transform(predicted_stock_price_gru)
predicted_stock_price_gru

# Get the real stock price of test set
real_stock_price=sc.inverse_transform(test_set_scaler[60:])
real_stock_price
# Calculate the RMSE value

plt.plot(real_stock_price,color='red',label='Mao Tai stock price') #Truth value is red line

plt.plot(predicted_stock_price_gru,color='blue',label='Mao Tai predicted stock price') #Predicted value is blue line

plt.title('Mao Tai Price Prediction of GRU model')

plt.xlabel('Time')

plt.ylabel('Stock Price')

plt.legend()
plt.show()
# Out:
# 8/8 [==============================] - 0s 8ms/step

# %%
# Calculate the RMSE value of LSTM model
mse_lstm=mean_squared_error(predicted_stock_price_lstm,real_stock_price)
rmse_lstm=math.sqrt(mse_lstm)

# Calculate the RMSE value of GRU model
mse_gru=mean_squared_error(predicted_stock_price_gru,real_stock_price)
rmse_gru=math.sqrt(mse_gru)

print('LSTM accury:')
print('MSE :%.6f'%mse_lstm)
print('RMSE :%.6f'%rmse_lstm)
print('GRU accury:')
print('MSE :%.6f'%mse_gru)
print('RMSE :%.6f'%rmse_gru)
# Out:
# LSTM accury:
# MSE :37847.106796
# RMSE :194.543329
# GRU accury:
# MSE :437.581220
# RMSE :20.918442

# %% [markdown]
# # Conclusion
# We found that GRU model has a lower RMSE value than LSTM model. It means that GRU model is more accurate than LSTM model for stock price prediction.

# %% [markdown]
# # Forecast Other Stock

# %%
# load other stock data
aapl = pd.read_csv('AAPL.csv')
aapl.head()
# Out:
#    Unnamed: 0        Date  Close     Volume    Open    High     Low
# 0           1  01/30/2014  17.85  678407529  $17.95  $18.09  $17.74
# 1           2  01/31/2014  17.88  464766494  $17.69  $17.91  $17.63
# 2           3  02/03/2014  17.91  401391319  $17.95  $18.13  $17.83
# 3           4  02/04/2014  18.17  376666769  $18.07  $18.20  $17.96
# 4           5  02/05/2014  18.31  328291189  $18.09  $18.40  $18.08

# %%
aapl.shape
# Out:
# (2517, 7)

# %%
plt.plot(aapl['Close'],color='blue',label='Stock Price')

# %%
# Top 2126 rows of data as training set, We only use the data of the opening price that is the close column 
training_set=aapl.iloc[:2517-300,2:3].values
# The last 300 rows of data are used as test set
test_set=aapl.iloc[2517-300:,2:3].values

# %%
print(training_set.shape)
print(test_set.shape)
# Out:
# (2217, 1)
# (300, 1)

# %%
# MinMaxScaler: Normalization to 0-1
sc=MinMaxScaler(feature_range=(0,1))
training_set_scaler=sc.fit_transform(training_set) 
test_set_scaler=sc.transform(test_set)

# %%
training_set_scaler
# Out:
# array([[0.00000000e+00],
#        [1.82748538e-04],
#        [3.65497076e-04],
#        ...,
#        [7.94529727e-01],
#        [8.05250975e-01],
#        [7.97636452e-01]])

# %%
test_set_scaler
# Out:
# array([[0.80939327],
#        [0.8128655 ],
#        [0.79288499],
#        [0.8061038 ],
#        [0.81152534],
#        [0.79349415],
#        [0.76979776],
#        [0.75121832],
#        [0.79300682],
#        [0.79471248],
#        [0.79166667],
#        [0.78447856],
#        [0.76181774],
#        [0.74981725],
#        [0.76023392],
#        [0.75724903],
#        [0.7714425 ],
#        [0.77741228],
#        [0.76364522],
#        [0.72277047],
#        [0.71064815],
#        [0.69761209],
#        [0.69718567],
#        [0.71637427],
#        [0.69675926],
#        [0.69450536],
#        [0.6833577 ],
#        [0.65905214],
#        [0.68079922],
#        [0.68274854],
#        [0.65314327],
#        [0.66100146],
#        [0.65283869],
#        [0.68086014],
#        [0.68408869],
#        [0.68762183],
#        [0.7044347 ],
#        [0.70394737],
#        [0.71217105],
#        [0.71935916],
#        [0.71491228],
#        [0.71527778],
#        [0.73111598],
#        [0.75085283],
#        [0.75950292],
#        [0.75542154],
#        [0.76821394],
#        [0.78021442],
#        [0.76236598],
#        [0.77022417],
#        [0.77716862],
#        [0.81000244],
#        [0.83241959],
#        [0.81554581],
#        [0.83333333],
#        [0.81670322],
#        [0.81030702],
#        [0.81115984],
#        [0.82846004],
#        [0.82450049],
#        [0.83747563],
#        [0.82760721],
#        [0.82054094],
#        [0.79574805],
#        [0.79836745],
#        [0.80135234],
#        [0.78496589],
#        [0.79233674],
#        [0.78923002],
#        [0.77643762],
#        [0.78009259],
#        [0.81128168],
#        [0.82833821],
#        [0.8147539 ],
#        [0.82249025],
#        [0.80860136],
#        [0.79586988],
#        [0.80787037],
#        [0.8207846 ],
#        [0.82322125],
#        [0.84064327],
#        [0.8354654 ],
#        [0.85008528],
#        [0.86153752],
#        [0.85270468],
#        [0.85940546],
#        [0.86744639],
#        [0.85544591],
#        [0.85160819],
#        [0.87061404],
#        [0.88029971],
#        [0.95102339],
#        [0.97295322],
#        [0.96734893],
#        [0.9830653 ],
#        [0.99884259],
#        [1.00536062],
#        [1.00243665],
#        [1.0267422 ],
#        [1.01699561],
#        [1.03307749],
#        [1.03654971],
#        [1.04690546],
#        [1.04678363],
#        [1.05750487],
#        [1.05257066],
#        [1.05665205],
#        [1.04848928],
#        [1.04739279],
#        [1.05110867],
#        [1.04483431],
#        [1.04836745],
#        [1.05622563],
#        [1.04519981],
#        [1.06950536],
#        [1.06280458],
#        [1.07468324],
#        [1.08345517],
#        [1.06804337],
#        [1.07736355],
#        [1.09716131],
#        [1.09807505],
#        [1.09478558],
#        [1.08455166],
#        [1.09094786],
#        [1.07809454],
#        [1.0771808 ],
#        [1.07060185],
#        [1.06725146],
#        [1.06786062],
#        [1.07048002],
#        [1.06408382],
#        [1.02211257],
#        [1.01364522],
#        [0.99939084],
#        [0.99494396],
#        [1.02162524],
#        [1.01906676],
#        [1.02546296],
#        [1.02180799],
#        [1.02381823],
#        [1.00986842],
#        [1.00408138],
#        [1.04032651],
#        [1.05817495],
#        [1.07236842],
#        [1.08022661],
#        [1.07608431],
#        [1.07407407],
#        [1.06341374],
#        [1.05921053],
#        [1.03673246]])

# %%
x_train,y_train,x_test,y_test=[],[],[],[]  # Create empty list
for i in range(60,len(training_set_scaler)):
    x_train.append(training_set_scaler[i-60:i,0])
    y_train.append(training_set_scaler[i,0])
    pass

# Convert the list to array format for train set

np.random.seed(7)
np.random.shuffle(x_train)
np.random.seed(7)
np.random.shuffle(y_train)
np.random.seed(7)

x_train,y_train=np.array(x_train),np.array(y_train)

x_train=np.reshape(x_train,(x_train.shape[0],60,1))

# %%
# convert the list to array format for test set
for i in range(60,len(test_set_scaler)):
    x_test.append(test_set_scaler[i-60:i,0])
    y_test.append(test_set_scaler[i,0])
    pass

x_test,y_test=np.array(x_test),np.array(y_test)

x_test=np.reshape(x_test,(x_test.shape[0],60,1))

# %%
# Train lstm model
history_lstm = lstm.fit(x_train, y_train, epochs=100, batch_size=32, 
          validation_data=(x_train, y_train), callbacks=[early_stopping])
lstm.summary() # Print model structure
# Out:
# Epoch 1/100
# 68/68 [==============================] - 4s 54ms/step - loss: 0.0732 - val_loss: 0.0671
# Epoch 2/100
# 68/68 [==============================] - 4s 52ms/step - loss: 0.0637 - val_loss: 0.0578
# Epoch 3/100
# 68/68 [==============================] - 4s 52ms/step - loss: 0.0547 - val_loss: 0.0491
# Epoch 4/100
# 68/68 [==============================] - 4s 56ms/step - loss: 0.0471 - val_loss: 0.0424
# Epoch 5/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.0404 - val_loss: 0.0356
# Epoch 6/100
# 68/68 [==============================] - 4s 53ms/step - loss: 0.0340 - val_loss: 0.0300
# Epoch 7/100
# 68/68 [==============================] - 3s 50ms/step - loss: 0.0288 - val_loss: 0.0257
# Epoch 8/100
# 68/68 [==============================] - 3s 48ms/step - loss: 0.0242 - val_loss: 0.0211
# Epoch 9/100
# 68/68 [==============================] - 3s 47ms/step - loss: 0.0204 - val_loss: 0.0175
# Epoch 10/100
# 68/68 [==============================] - 3s 48ms/step - loss: 0.0172 - val_loss: 0.0158
# Epoch 11/100
# 68/68 [==============================] - 3s 47ms/step - loss: 0.0143 - val_loss: 0.0116
# Epoch 12/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.0117 - val_loss: 0.0093
# Epoch 13/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.0095 - val_loss: 0.0075
# Epoch 14/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.0078 - val_loss: 0.0060
# Epoch 15/100
# 68/68 [==============================] - 3s 47ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 16/100
# 68/68 [==============================] - 3s 47ms/step - loss: 0.0054 - val_loss: 0.0040
# Epoch 17/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.0044 - val_loss: 0.0029
# Epoch 18/100
# 68/68 [==============================] - 3s 47ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 19/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 20/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 21/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 22/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.0019 - val_loss: 9.0681e-04
# Epoch 23/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.0016 - val_loss: 6.9610e-04
# Epoch 24/100
# 68/68 [==============================] - 4s 64ms/step - loss: 0.0016 - val_loss: 5.7153e-04
# Epoch 25/100
# 68/68 [==============================] - 4s 60ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 26/100
# 68/68 [==============================] - 4s 60ms/step - loss: 0.0015 - val_loss: 6.9919e-04
# Epoch 27/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0014 - val_loss: 5.8753e-04
# Epoch 28/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0015 - val_loss: 4.9838e-04
# Epoch 29/100
# 68/68 [==============================] - 4s 61ms/step - loss: 0.0015 - val_loss: 6.8678e-04
# Epoch 30/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0013 - val_loss: 4.7591e-04
# Epoch 31/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.0014 - val_loss: 4.7268e-04
# Epoch 32/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.0012 - val_loss: 7.6313e-04
# Epoch 33/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0014 - val_loss: 4.5212e-04
# Epoch 34/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0014 - val_loss: 4.4248e-04
# Epoch 35/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0014 - val_loss: 7.3273e-04
# Epoch 36/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0015 - val_loss: 4.7237e-04
# Epoch 37/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.0013 - val_loss: 4.3523e-04
# Epoch 38/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0013 - val_loss: 4.3463e-04
# Epoch 39/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.0012 - val_loss: 6.7664e-04
# Epoch 40/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0012 - val_loss: 6.4424e-04
# Epoch 41/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0013 - val_loss: 4.3885e-04
# Epoch 42/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0013 - val_loss: 6.0908e-04
# Epoch 43/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0013 - val_loss: 4.9966e-04
# Epoch 44/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0014 - val_loss: 9.4240e-04
# Epoch 45/100
# 68/68 [==============================] - 4s 59ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 46/100
# 68/68 [==============================] - 4s 62ms/step - loss: 0.0014 - val_loss: 4.3675e-04
# Epoch 47/100
# 68/68 [==============================] - 4s 59ms/step - loss: 0.0012 - val_loss: 4.0450e-04
# Epoch 48/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0012 - val_loss: 4.5414e-04
# Epoch 49/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.0012 - val_loss: 5.1976e-04
# Epoch 50/100
# 68/68 [==============================] - 4s 59ms/step - loss: 0.0012 - val_loss: 3.9496e-04
# Epoch 51/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.0012 - val_loss: 5.1267e-04
# Epoch 52/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0012 - val_loss: 4.3349e-04
# Epoch 53/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.0013 - val_loss: 6.9862e-04
# Epoch 54/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0011 - val_loss: 3.8934e-04
# Epoch 55/100
# 68/68 [==============================] - 4s 58ms/step - loss: 9.0180e-04 - val_loss: 4.9255e-04
# Epoch 56/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0012 - val_loss: 4.6533e-04
# Epoch 57/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0013 - val_loss: 6.6493e-04
# Epoch 58/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0013 - val_loss: 4.4010e-04
# Epoch 59/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.0010 - val_loss: 3.5588e-04
# Epoch 60/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0010 - val_loss: 4.5749e-04
# Epoch 61/100
# 68/68 [==============================] - 4s 57ms/step - loss: 0.0011 - val_loss: 3.6821e-04
# Epoch 62/100
# 68/68 [==============================] - 4s 60ms/step - loss: 0.0011 - val_loss: 6.8884e-04
# Epoch 63/100
# 68/68 [==============================] - 4s 60ms/step - loss: 0.0010 - val_loss: 8.6510e-04
# Epoch 64/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0011 - val_loss: 3.9265e-04
# Epoch 65/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.0010 - val_loss: 6.3500e-04
# Epoch 66/100
# 68/68 [==============================] - 4s 58ms/step - loss: 0.
# 68/68 [==============================] - 5s 67ms/step - loss: 0.0010 - val_loss: 3.7082e-04
# Epoch 97/100
# 68/68 [==============================] - 5s 67ms/step - loss: 9.4239e-04 - val_loss: 3.1377e-04
# Epoch 98/100
# 68/68 [==============================] - 4s 65ms/step - loss: 9.6640e-04 - val_loss: 3.2250e-04
# Epoch 99/100
# 68/68 [==============================] - 5s 67ms/step - loss: 0.0011 - val_loss: 6.9470e-04
# Epoch 100/100
# 68/68 [==============================] - 5s 70ms/step - loss: 0.0011 - val_loss: 3.4460e-04
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 60, 100)           40800
#
#  dropout_4 (Dropout)         (None, 60, 100)           0
#
#  lstm_4 (LSTM)               (None, 60, 50)            30200
#
#  dropout_5 (Dropout)         (None, 60, 50)            0
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dropout_6 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 91251 (356.45 KB)
# Trainable params: 91251 (356.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train gru model
history_gru = gru.fit(x_train, y_train, epochs=100, batch_size=32, 
          validation_data=(x_train, y_train), callbacks=[early_stopping])
gru.summary() # Print model structure
# Out:
# Epoch 1/100
# 68/68 [==============================] - 3s 29ms/step - loss: 0.0096 - val_loss: 2.1694e-04
# Epoch 2/100
# 68/68 [==============================] - 2s 25ms/step - loss: 0.0011 - val_loss: 2.0035e-04
# Epoch 3/100
# 68/68 [==============================] - 2s 24ms/step - loss: 9.8675e-04 - val_loss: 2.0088e-04
# Epoch 4/100
# 68/68 [==============================] - 2s 25ms/step - loss: 8.1158e-04 - val_loss: 1.6238e-04
# Epoch 5/100
# 68/68 [==============================] - 2s 26ms/step - loss: 7.6840e-04 - val_loss: 1.5431e-04
# Epoch 6/100
# 68/68 [==============================] - 2s 28ms/step - loss: 6.8846e-04 - val_loss: 1.8160e-04
# Epoch 7/100
# 68/68 [==============================] - 2s 35ms/step - loss: 6.7856e-04 - val_loss: 1.7273e-04
# Epoch 8/100
# 68/68 [==============================] - 2s 34ms/step - loss: 7.6479e-04 - val_loss: 1.5033e-04
# Epoch 9/100
# 68/68 [==============================] - 2s 28ms/step - loss: 6.3905e-04 - val_loss: 1.9206e-04
# Epoch 10/100
# 68/68 [==============================] - 2s 32ms/step - loss: 6.3323e-04 - val_loss: 2.1853e-04
# Epoch 11/100
# 68/68 [==============================] - 2s 32ms/step - loss: 6.1648e-04 - val_loss: 1.4204e-04
# Epoch 12/100
# 68/68 [==============================] - 2s 30ms/step - loss: 5.6484e-04 - val_loss: 1.4552e-04
# Epoch 13/100
# 68/68 [==============================] - 2s 28ms/step - loss: 6.3692e-04 - val_loss: 1.4428e-04
# Epoch 14/100
# 68/68 [==============================] - 2s 28ms/step - loss: 6.0488e-04 - val_loss: 1.5040e-04
# Epoch 15/100
# 68/68 [==============================] - 2s 28ms/step - loss: 5.0732e-04 - val_loss: 1.7181e-04
# Epoch 16/100
# 68/68 [==============================] - 2s 28ms/step - loss: 5.2308e-04 - val_loss: 1.2649e-04
# Epoch 17/100
# 68/68 [==============================] - 2s 28ms/step - loss: 5.0600e-04 - val_loss: 1.2920e-04
# Epoch 18/100
# 68/68 [==============================] - 2s 28ms/step - loss: 5.4010e-04 - val_loss: 1.3768e-04
# Epoch 19/100
# 68/68 [==============================] - 2s 28ms/step - loss: 5.4027e-04 - val_loss: 1.3166e-04
# Epoch 20/100
# 68/68 [==============================] - 2s 28ms/step - loss: 5.5003e-04 - val_loss: 1.6462e-04
# Epoch 21/100
# 68/68 [==============================] - 2s 29ms/step - loss: 6.1193e-04 - val_loss: 3.4740e-04
# Epoch 22/100
# 68/68 [==============================] - 2s 27ms/step - loss: 5.2579e-04 - val_loss: 1.2958e-04
# Epoch 23/100
# 68/68 [==============================] - 2s 27ms/step - loss: 4.7287e-04 - val_loss: 1.5933e-04
# Epoch 24/100
# 68/68 [==============================] - 2s 28ms/step - loss: 4.7540e-04 - val_loss: 2.6499e-04
# Epoch 25/100
# 68/68 [==============================] - 2s 28ms/step - loss: 5.4387e-04 - val_loss: 1.5717e-04
# Epoch 26/100
# 68/68 [==============================] - 2s 28ms/step - loss: 4.5842e-04 - val_loss: 1.4260e-04
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 128)               50304
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 50433 (197.00 KB)
# Trainable params: 50433 (197.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Draw the loss curve of LSTM model
data={}
data['loss']=history_lstm.history['loss']

data['val_loss']=history_lstm.history['val_loss']
pd.DataFrame(data).plot(figsize=(8,5))
plt.grid(True)
plt.title('Training and Validation Loss of LSTM model')
plt.legend()
plt.show()

# %%
# Draw the loss curve of GRU model
data={}
data['loss']=history_gru.history['loss']

data['val_loss']=history_gru.history['val_loss']
pd.DataFrame(data).plot(figsize=(8,5))
plt.grid(True)
plt.title('Training and Validation Loss of GRU model')
plt.legend()
plt.show()

# %%
# Predict stock price of test set by LSTM model 
predicted_stock_price_lstm=lstm.predict(x_test)
# Inverse normalization to get the real stock price 
predicted_stock_price_lstm=sc.inverse_transform(predicted_stock_price_lstm)
predicted_stock_price_lstm

# Get the real stock price of test set
real_stock_price=sc.inverse_transform(test_set_scaler[60:])
real_stock_price
# Calculate the RMSE value

plt.plot(real_stock_price,color='red',label='Mao Tai stock price') #Truth value is red line

plt.plot(predicted_stock_price_lstm,color='blue',label='Mao Tai predicted stock price') #Predicted value is blue line

plt.title('Mao Tai Price Prediction of LSTM model')

plt.xlabel('Time')

plt.ylabel('Stock Price')

plt.legend()
plt.show()
# Out:
# 8/8 [==============================] - 1s 21ms/step

# %%
# Predict stock price of test set by GRU model 
predicted_stock_price_gru=gru.predict(x_test)
# Inverse normalization to get the real stock price 
predicted_stock_price_gru=sc.inverse_transform(predicted_stock_price_gru)
predicted_stock_price_gru

# Get the real stock price of test set
real_stock_price=sc.inverse_transform(test_set_scaler[60:])
real_stock_price
# Calculate the RMSE value

plt.plot(real_stock_price,color='red',label='Mao Tai stock price') #Truth value is red line

plt.plot(predicted_stock_price_gru,color='blue',label='Mao Tai predicted stock price') #Predicted value is blue line

plt.title('Mao Tai Price Prediction of GRU model')

plt.xlabel('Time')

plt.ylabel('Stock Price')

plt.legend()
plt.show()
# Out:
# 8/8 [==============================] - 0s 9ms/step

# %%
# Calculate the RMSE value of LSTM model
mse_lstm=mean_squared_error(predicted_stock_price_lstm,real_stock_price)
rmse_lstm=math.sqrt(mse_lstm)

# Calculate the RMSE value of GRU model
mse_gru=mean_squared_error(predicted_stock_price_gru,real_stock_price)
rmse_gru=math.sqrt(mse_gru)

print('LSTM accury:')
print('MSE :%.6f'%mse_lstm)
print('RMSE :%.6f'%rmse_lstm)
print('GRU accury:')
print('MSE :%.6f'%mse_gru)
print('RMSE :%.6f'%rmse_gru)
# Out:
# LSTM accury:
# MSE :14.415111
# RMSE :3.796724
# GRU accury:
# MSE :9.256863
# RMSE :3.042509
